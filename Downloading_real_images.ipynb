# %% [markdown]
# <a href="https://colab.research.google.com/github/Rumas0/Thesis_work_SSL-imbalance/blob/main/Downloading_real_images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Mounting Drive and loading images**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import os
import requests
from tqdm import tqdm
from google.colab import drive

# %%
backup_dir = '/content/drive/MyDrive/Thesis-work/Backups/thesis_backup_day1'

train_df = pd.read_csv(f'{backup_dir}/expA_train.csv')
val_df = pd.read_csv(f'{backup_dir}/expA_val.csv')
test_df = pd.read_csv(f'{backup_dir}/expA_test.csv')

all_images = pd.concat([train_df, val_df, test_df])['image'].unique()
print(f"Total unique images needed: {len(all_images)}")

os.makedirs('data/labeled_real', exist_ok=True)
# Out:
# Total unique images needed: 691

# %% [markdown]
# #**Kaggle Download**

# %% [markdown]
# **Setup Kaggle API**

# %%
from google.colab import files
print("Upload kaggle.json API token:")
files.upload()

# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# !ls -ls ~/.kaggle/kaggle.json
# Out:
# Upload kaggle.json API token:
#      <input type="file" id="files-2ea3d0f9-49e9-4bc9-8b1d-86a61415788a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2ea3d0f9-49e9-4bc9-8b1d-86a61415788a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %% [markdown]
# **Downloading ISIC 2019**

# %%
# !kaggle datasets download -d bhanupratapbiswas/isic-2019

# !unzip -q isic-2019.zip -d data/isic2019_full/
print("Download Completed")
# Out:
# 403 Client Error: Forbidden for url: https://api.kaggle.com/v1/datasets.DatasetApiService/GetDatasetMetadata
# unzip:  cannot find or open isic-2019.zip, isic-2019.zip.zip or isic-2019.zip.ZIP.
# Download Completed

# %% [markdown]
# **Note: Kaggle API and ISIC direct download encountered 403 errors
#  *# Real images obtained via manual download from ISIC Archive
#  *# URL: https://challenge.isic-archive.com/data/
# *# File: ISIC_2019_Training_Input.zip (~9GB)**
